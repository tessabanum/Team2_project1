# %%
# %matplotlib inline
import statsmodels.api as sm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
csv = pd.read_csv('NewListAll2014-UPDATE01.csv')

df = pd.DataFrame(csv)
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'State_y'])
df = df.set_index('FIPS')
df.head()
# Out:
#      State_x       Area_Name POP_ESTIMATE_2014 HH_income_2014  \
# FIPS
# 1001      AL  Autauga County            54,876         54,366
# 1003      AL  Baldwin County           199,189         49,626
# 1005      AL  Barbour County            26,758         34,971
# 1007      AL     Bibb County            22,541         39,546
# 1009      AL   Blount County            57,521         45,567
#
#       Unemployment_rate_2014  Alcohol Mortality Rate  \
# FIPS
# 1001                     5.8                    1.45
# 1003                     6.1                    2.53
# 1005                    10.5                    2.72
# 1007                     7.2                    1.22
# 1009                     6.1                    1.31
#
#       Alcohol Mortality Rate(F)  Alcohol Mortality Rate(M)  \
# FIPS
# 1001                       0.90                       2.11
# 1003                       1.88                       3.36
# 1005                       1.89                       3.57
# 1007                       0.70                       1.92
# 1009                       0.77                       2.03
#
#       Drug Mortality Rate  Drug Mortality Rate(F)  ...  HPSA Score  \
# FIPS                                               ...
# 1001                 7.32                    5.17  ...          16
# 1003                13.30                   11.24  ...          15
# 1005                 5.40                    3.35  ...          12
# 1007                13.03                    9.76  ...          19
# 1009                14.38                   11.55  ...          18
#
#       HPSA Shortage          County  County Code  Mental Deaths  \
# FIPS
# 1001           6.96  Autauga County       1001.0           17.0
# 1003           1.03  Baldwin County       1003.0           97.0
# 1005           0.93  Barbour County       1005.0           11.0
# 1007           0.00     Bibb County       1007.0           10.0
# 1009          16.66   Blount County       1009.0           24.0
#
#       Alcohol Deaths  Drug Deaths Total Deaths Population McDonalds Count
# FIPS
# 1001             NaN          NaN         17.0    55395.0               1
# 1003            18.0         40.0        155.0   200111.0              11
# 1005             NaN          NaN         11.0    26887.0               1
# 1007             NaN          NaN         10.0    22506.0               1
# 1009             NaN         12.0         36.0    57719.0               2
#
# [5 rows x 35 columns]

# %%
bins = [0, 15, 50, 400]

group = ['Low McDonalds', 'Middle McDonalds', 'High McDonalds']

# %%
df['HH_income_2014'] = (df['HH_income_2014'].replace(',', '', regex=True).astype(float))

df.head()
# Out:
#      State_x       Area_Name POP_ESTIMATE_2014  HH_income_2014  \
# FIPS
# 1001      AL  Autauga County            54,876         54366.0
# 1003      AL  Baldwin County           199,189         49626.0
# 1005      AL  Barbour County            26,758         34971.0
# 1007      AL     Bibb County            22,541         39546.0
# 1009      AL   Blount County            57,521         45567.0
#
#       Unemployment_rate_2014  Alcohol Mortality Rate  \
# FIPS
# 1001                     5.8                    1.45
# 1003                     6.1                    2.53
# 1005                    10.5                    2.72
# 1007                     7.2                    1.22
# 1009                     6.1                    1.31
#
#       Alcohol Mortality Rate(F)  Alcohol Mortality Rate(M)  \
# FIPS
# 1001                       0.90                       2.11
# 1003                       1.88                       3.36
# 1005                       1.89                       3.57
# 1007                       0.70                       1.92
# 1009                       0.77                       2.03
#
#       Drug Mortality Rate  Drug Mortality Rate(F)  ...  HPSA Score  \
# FIPS                                               ...
# 1001                 7.32                    5.17  ...          16
# 1003                13.30                   11.24  ...          15
# 1005                 5.40                    3.35  ...          12
# 1007                13.03                    9.76  ...          19
# 1009                14.38                   11.55  ...          18
#
#       HPSA Shortage          County  County Code  Mental Deaths  \
# FIPS
# 1001           6.96  Autauga County       1001.0           17.0
# 1003           1.03  Baldwin County       1003.0           97.0
# 1005           0.93  Barbour County       1005.0           11.0
# 1007           0.00     Bibb County       1007.0           10.0
# 1009          16.66   Blount County       1009.0           24.0
#
#       Alcohol Deaths  Drug Deaths Total Deaths Population McDonalds Count
# FIPS
# 1001             NaN          NaN         17.0    55395.0               1
# 1003            18.0         40.0        155.0   200111.0              11
# 1005             NaN          NaN         11.0    26887.0               1
# 1007             NaN          NaN         10.0    22506.0               1
# 1009             NaN         12.0         36.0    57719.0               2
#
# [5 rows x 35 columns]

# %%
df["McDonalds Grouping"] = pd.cut(df["McDonalds Count"], bins, labels=group)

df.head()
# Out:
#      State_x       Area_Name POP_ESTIMATE_2014  HH_income_2014  \
# FIPS
# 1001      AL  Autauga County            54,876         54366.0
# 1003      AL  Baldwin County           199,189         49626.0
# 1005      AL  Barbour County            26,758         34971.0
# 1007      AL     Bibb County            22,541         39546.0
# 1009      AL   Blount County            57,521         45567.0
#
#       Unemployment_rate_2014  Alcohol Mortality Rate  \
# FIPS
# 1001                     5.8                    1.45
# 1003                     6.1                    2.53
# 1005                    10.5                    2.72
# 1007                     7.2                    1.22
# 1009                     6.1                    1.31
#
#       Alcohol Mortality Rate(F)  Alcohol Mortality Rate(M)  \
# FIPS
# 1001                       0.90                       2.11
# 1003                       1.88                       3.36
# 1005                       1.89                       3.57
# 1007                       0.70                       1.92
# 1009                       0.77                       2.03
#
#       Drug Mortality Rate  Drug Mortality Rate(F)  ...  HPSA Shortage  \
# FIPS                                               ...
# 1001                 7.32                    5.17  ...           6.96
# 1003                13.30                   11.24  ...           1.03
# 1005                 5.40                    3.35  ...           0.93
# 1007                13.03                    9.76  ...           0.00
# 1009                14.38                   11.55  ...          16.66
#
#               County  County Code  Mental Deaths  Alcohol Deaths  Drug Deaths  \
# FIPS
# 1001  Autauga County       1001.0           17.0             NaN          NaN
# 1003  Baldwin County       1003.0           97.0            18.0         40.0
# 1005  Barbour County       1005.0           11.0             NaN          NaN
# 1007     Bibb County       1007.0           10.0             NaN          NaN
# 1009   Blount County       1009.0           24.0             NaN         12.0
#
#       Total Deaths Population McDonalds Count McDonalds Grouping
# FIPS
# 1001          17.0    55395.0               1      Low McDonalds
# 1003         155.0   200111.0              11      Low McDonalds
# 1005          11.0    26887.0               1      Low McDonalds
# 1007          10.0    22506.0               1      Low McDonalds
# 1009          36.0    57719.0               2      Low McDonalds
#
# [5 rows x 36 columns]

# %%
df_low = (df['McDonalds Grouping'] == 'Low McDonalds')
df_mid = df['McDonalds Grouping'] == 'Middle McDonalds'
df_Up = df['McDonalds Grouping'] == 'High McDonalds'

# %%
df_lowIncome = df[df_low]
df_midIncome = df[df_mid]
df_UpIncome = df[df_Up]

# %%
# dfM = df['Mental Deaths'] > 0
# df_Master = df[dfM]

dfM1 = df_lowIncome['Alcohol Deaths'] > 0
df_Master1 = df_lowIncome[dfM1]

dfM2 = df_midIncome['Alcohol Deaths'] > 0
df_Master2 = df_midIncome[dfM2]

dfM3 = df_UpIncome['Alcohol Deaths'] > 0
df_Master3 = df_UpIncome[dfM3]

# %%
# X = df_Master['Mental Deaths']
# Y = df_Master['McDonalds Count']

X1 = df_Master1['McDonalds Count']
Y1 = df_Master1['Alcohol Deaths']

X2 = df_Master2['McDonalds Count']
Y2 = df_Master2['Alcohol Deaths']

X3 = df_Master3['McDonalds Count']
Y3 = df_Master3['Alcohol Deaths']

# %%
# plt.scatter(X, Y, alpha=0.95, c='g')
# z = np.polyfit(X, Y, 1)
# p = np.poly1d(z)
# plt.plot(X, p(X), "r--")
# plt.xlabel('Mental Health Deaths')
# plt.ylabel('Number of McDonalds')
# plt.legend()
# plt.grid()
# plt.title('Mental Health Deaths and McDonalds')
# plt.show()

plt.scatter(X1, Y1, alpha=0.95, c='b')
z = np.polyfit(X1, Y1, 1)
p = np.poly1d(z)
plt.plot(X1, p(X1), "r--")
plt.xlabel('Number of McDonalds')
plt.ylabel('Alcohol Deaths')
plt.legend()
plt.grid()
plt.title('Alcohol Deaths in Less Areas with McDonalds')
plt.show()
slope, intercept, r_value, p_value, std_err = stats.linregress(X1, Y1)

print(f'R-sqaured: {r_value**2}')


plt.scatter(X2, Y2, alpha=0.95, c='r')
z = np.polyfit(X2, Y2, 1)
p = np.poly1d(z)
plt.plot(X2, p(X2), "r--")
plt.xlabel('Number of McDonalds')
plt.ylabel('Alcohol Deaths')
plt.legend()
plt.grid()
plt.title('Alcohol Deaths in Middle Areas with McDonalds')
plt.show()
slope, intercept, r_value, p_value, std_err = stats.linregress(X2, Y2)

print(f'R-sqaured: {r_value**2}')

plt.scatter(X3, Y3, alpha=0.95, c='y')
z = np.polyfit(X3, Y3, 1)
p = np.poly1d(z)
plt.plot(X3, p(X3), "r--")
plt.xlabel('Number of McDonalds')
plt.ylabel('Alcohol Deaths')
plt.legend()
plt.grid()
plt.title('Alcohol Deaths in High Areas with McDonalds')
plt.show()
slope, intercept, r_value, p_value, std_err = stats.linregress(X3, Y3)

print(f'R-sqaured: {r_value**2}')
# Out:
# R-sqaured: 0.1903821181989633
# R-sqaured: 0.39857305493604767
# R-sqaured: 0.7167100044597848

# %%
Xa = df_Master3[['McDonalds Count', 'HH_income_2014', 'Unemployment_rate_2014']]
Ya = df_Master3['Alcohol Deaths']
Ra = sm.add_constant(Xa)
rega = sm.OLS(Ya.astype(float), Xa.astype(float)).fit()

Xb = df_Master3[['McDonalds Count', 'HH_income_2014']] 
Yb = df_Master3['Alcohol Deaths']
Rb = sm.add_constant(Xb)
regb = sm.OLS(Yb.astype(float), Xb.astype(float)).fit()

Xc = df_Master3[['McDonalds Count', 'Unemployment_rate_2014']]
Yc = df_Master3['Alcohol Deaths']
Rc = sm.add_constant(Xc)
regc = sm.OLS(Yc.astype(float), Xc.astype(float)).fit()

rega.summary(), regb.summary(), regc.summary()
# Out:
# C:\Users\Owner\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:         Alcohol Deaths   R-squared (uncentered):                   0.873
#  Model:                            OLS   Adj. R-squared (uncentered):              0.857
#  Method:                 Least Squares   F-statistic:                              55.00
#  Date:                Tue, 30 Jul 2019   Prob (F-statistic):                    6.66e-11
#  Time:                        00:41:43   Log-Likelihood:                         -166.08
#  No. Observations:                  27   AIC:                                      338.2
#  Df Residuals:                      24   BIC:                                      342.0
#  Df Model:                           3
#  Covariance Type:            nonrobust
#  ==========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------------------
#  McDonalds Count            2.6325      0.372      7.069      0.000       1.864       3.401
#  HH_income_2014            -0.0003      0.001     -0.231      0.820      -0.003       0.002
#  Unemployment_rate_2014     0.4758     12.248      0.039      0.969     -24.803      25.755
#  ==============================================================================
#  Omnibus:                        0.504   Durbin-Watson:                   0.738
#  Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.156
#  Skew:                           0.186   Prob(JB):                        0.925
#  Kurtosis:                       3.000   Cond. No.                     3.10e+04
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 3.1e+04. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """, <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:         Alcohol Deaths   R-squared (uncentered):                   0.873
#  Model:                            OLS   Adj. R-squared (uncentered):              0.863
#  Method:                 Least Squares   F-statistic:                              85.93
#  Date:                Tue, 30 Jul 2019   Prob (F-statistic):                    6.27e-12
#  Time:                        00:41:43   Log-Likelihood:                         -166.08
#  No. Observations:                  27   AIC:                                      336.2
#  Df Residuals:                      25   BIC:                                      338.8
#  Df Model:                           2
#  Covariance Type:            nonrobust
#  ===================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
#  -----------------------------------------------------------------------------------
#  McDonalds Count     2.6391      0.325      8.125      0.000       1.970       3.308
#  HH_income_2014     -0.0002      0.001     -0.366      0.718      -0.002       0.001
#  ==============================================================================
#  Omnibus:                        0.499   Durbin-Watson:                   0.741
#  Prob(Omnibus):                  0.779   Jarque-Bera (JB):                0.147
#  Skew:                           0.180   Prob(JB):                        0.929
#  Kurtosis:                       3.005   Cond. No.                         840.
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """, <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:         Alcohol Deaths   R-squared (uncentered):                   0.873
#  Model:                            OLS   Adj. R-squared (uncentered):              0.863
#  Method:                 Least Squares   F-statistic:                              85.72
#  Date:                Tue, 30 Jul 2019   Prob (F-statistic):                    6.44e-12
#  Time:                        00:41:43   Log-Likelihood:                         -166.11
#  No. Observations:                  27   AIC:                                      336.2
#  Df Residuals:                      25   BIC:                                      338.8
#  Df Model:                           2
#  Covariance Type:            nonrobust
#  ==========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------------------
#  McDonalds Count            2.6311      0.365      7.204      0.000       1.879       3.383
#  Unemployment_rate_2014    -1.8767      6.653     -0.282      0.780     -15.579      11.825
#  ==============================================================================
#  Omnibus:                        0.797   Durbin-Watson:                   0.740
#  Prob(Omnibus):                  0.671   Jarque-Bera (JB):                0.271
#  Skew:                           0.240   Prob(JB):                        0.873
#  Kurtosis:                       3.098   Cond. No.                         34.3
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)
